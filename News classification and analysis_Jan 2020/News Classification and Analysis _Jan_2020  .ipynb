# %%
#importing all the required libraries
import selenium
import pandas as pd
from selenium import webdriver # Importing selenium webdriver 

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
driver=webdriver.Chrome("/Users/nlohith/Desktop/chromedriver")

# %%
# Opening the url
driver.get('https://timesofindia.indiatimes.com/archive/year-2020,month-1.cms')

# %%
#creating empty lists
Date=[]
Author=[]
Vertical=[]
Headline=[]
Description=[]

# %%
url=[]
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[3]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[4]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[5]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[6]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[7]/a"):
    url.append(i.get_attribute("href"))    
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[3]/td/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[4]/td/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[5]/td/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[6]/td[1]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[6]/td[2]/a"):
    url.append(i.get_attribute("href"))  
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[6]/td[3]/a"):
    url.append(i.get_attribute("href"))    
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[6]/td[4]/a"):
    url.append(i.get_attribute("href"))    
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[6]/td[5]/a"):
    url.append(i.get_attribute("href"))

# %%
url
# Out:
# ['https://timesofindia.indiatimes.com/2020/1/1/archivelist/year-2020,month-1,starttime-43831.cms',
#  'https://timesofindia.indiatimes.com/2020/1/1/archivelist/year-2020,month-1,starttime-43831.cms',
#  'https://timesofindia.indiatimes.com/2020/1/2/archivelist/year-2020,month-1,starttime-43832.cms',
#  'https://timesofindia.indiatimes.com/2020/1/3/archivelist/year-2020,month-1,starttime-43833.cms',
#  'https://timesofindia.indiatimes.com/2020/1/4/archivelist/year-2020,month-1,starttime-43834.cms',
#  'https://timesofindia.indiatimes.com/2020/1/5/archivelist/year-2020,month-1,starttime-43835.cms',
#  'https://timesofindia.indiatimes.com/2020/1/6/archivelist/year-2020,month-1,starttime-43836.cms',
#  'https://timesofindia.indiatimes.com/2020/1/7/archivelist/year-2020,month-1,starttime-43837.cms',
#  'https://timesofindia.indiatimes.com/2020/1/8/archivelist/year-2020,month-1,starttime-43838.cms',
# ...

# %%
#opening the first url i.e., 1st may
driver.get(url[0])
URLS1=[] #appending all the urls of the news from 1st may
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS1.append(i.get_attribute("href"))

# %%
for i in URLS1[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[1])
URLS2=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS2.append(i.get_attribute("href"))

# %%
for i in URLS2[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[2])
URLS3=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS3.append(i.get_attribute("href"))

# %%
for i in URLS3[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[3])
URLS4=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS4.append(i.get_attribute("href"))

# %%
for i in URLS4[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[4])
URLS5=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS5.append(i.get_attribute("href"))

# %%
for i in URLS5[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[5])
URLS6=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS6.append(i.get_attribute("href"))

# %%
for i in URLS6[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[6])
URLS7=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS7.append(i.get_attribute("href"))

# %%
for i in URLS7[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[7])
URLS8=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS8.append(i.get_attribute("href"))

# %%
for i in URLS8[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[8])
URLS9=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS9.append(i.get_attribute("href"))

# %%
for i in URLS9[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[9])
URLS10=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS10.append(i.get_attribute("href"))

# %%
for i in URLS10[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[10])
URLS11=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS11.append(i.get_attribute("href"))

# %%
for i in URLS11[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[11])
URLS12=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS12.append(i.get_attribute("href"))

# %%
for i in URLS12[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[12])
URLS13=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS13.append(i.get_attribute("href"))

# %%
for i in URLS13[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[13])
URLS14=[]
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS14.append(i.get_attribute("href"))

# %%
for i in URLS14[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[14])
URLS15=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS15.append(i.get_attribute("href"))

# %%
for i in URLS15[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[15])
URLS16=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS16.append(i.get_attribute("href"))

# %%
for i in URLS16[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[16])
URLS17=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS17.append(i.get_attribute("href"))

# %%
for i in URLS17[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[17])
URLS18=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS18.append(i.get_attribute("href"))

# %%
for i in URLS18[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[18])
URLS19=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS19.append(i.get_attribute("href"))

# %%
for i in URLS19[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[19])
URLS20=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS20.append(i.get_attribute("href"))

# %%
for i in URLS20[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[20])
URLS21=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS21.append(i.get_attribute("href"))

# %%
for i in URLS21[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[21])
URLS22=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS22.append(i.get_attribute("href"))

# %%
for i in URLS22[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[22])
URLS23=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS23.append(i.get_attribute("href"))

# %%
for i in URLS23[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[23])
URLS24=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS24.append(i.get_attribute("href"))

# %%
for i in URLS24[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[24])
URLS25=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS25.append(i.get_attribute("href"))

# %%
for i in URLS25[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[25])
URLS26=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS26.append(i.get_attribute("href"))

# %%
for i in URLS26[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[26])
URLS27=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS27.append(i.get_attribute("href"))

# %%
for i in URLS27[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[27])
URLS28=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS28.append(i.get_attribute("href"))

# %%
for i in URLS28[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[28])
URLS29=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS29.append(i.get_attribute("href"))

# %%
for i in URLS29[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[29])
URLS30=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS30.append(i.get_attribute("href"))

# %%
for i in URLS30[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[30])
URLS31=[] 
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS31.append(i.get_attribute("href"))

# %%
for i in URLS31[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
print(len(Date),len(Description),len(Headline),len(Vertical),len(Author))
# Out:
# 620 620 620 620 620

# %%
#creating a dataframe
import pandas as pd
News=pd.DataFrame({})
News['Date']=Date
News['Author']=Author
News['Vertical']=Vertical
News['Headline']=Headline
News['Description']=Description
News
# Out:
#                                                   Date  \
# 0                      Created: Jan 1, 2020, 00:00 IST
# 1                     Updated: Jun 29, 2020, 00:35 IST
# 2                         TNN | Jan 1, 2020, 00:00 IST
# 3                      Created: Jan 1, 2020, 00:00 IST
# 4                      Created: Jan 1, 2020, 00:00 IST
# ..                                                 ...
# 615  SUBSCRIBE NOW\nGet a weekly dose of all the ma...
# 616  TIMESOFINDIA.COM | Updated: Jan 30, 2020, 22:1...
# 617             FLAVIO LOPES | Jan 30, 2020, 00:21 IST
# 618  Manyaekta Gugliani | TNN | Jan 30, 2020, 00:43...
# 619        Meera Vohra | TNN | Jan 30, 2020, 01:00 IST
#
#                                Author       Vertical  \
# 0                       Tanvi Trivedi             TV
# 1                 Joyeeta Chakravorty      Lifestyle
# 2                                   -           City
# 3                   KAVYA CHRISTOPHER  Entertainment
# ...

# %%
#Saving our dataframe into csv file
News.to_csv('Jan_News_2020.csv', index = False)
